# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_data = np.arange(9)

# %%
# %matplotlib notebook

# %%
plt.plot(new_data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline

# %%
plt.plot(new_data)

# %%
plt.title("the new data graph")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'the new data graph')

# %%
# %matplotlib notebook

# %%
new_data = np.arange(9)
plt.title("the new data graph")
plt.xlabel("x label data")
plt.ylabel("y label data")
plt.plot(new_data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'y label data')

# %%
x = [1,2,3,4,5,6,7]
y = [1,4,9,16,25,36,49]

# %%
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # matplotlib level4

# %%
# %matplotlib notebook

# %%
data1 = np.arange(2,7,0.3)

# %%
plt.plot(data1, data1, "r--", data1, data1**2, "bs", data1, data1**3, "g^")
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x2a19974c248>,
#  <matplotlib.lines.Line2D at 0x2a19974cac8>,
#  <matplotlib.lines.Line2D at 0x2a199bb1048>]

# %%
# to save this graph

# %%
plt.savefig("graph_name.png")

# %%
new_files = ["film1","film2","film3","film4"]
awards = [3,4,5,6]

# %%
plt.bar(range(len(new_files)),awards)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.title("the top films")
# Out:
# Text(0.5, 1.0, 'the top films')

# %%
plt.ylabel("no of wards")
# Out:
# Text(47.902777777777786, 0.5, 'no of wards')

# %%
plt.xticks(range(len(new_files)),new_files)
# Out:
# ([<matplotlib.axis.XTick at 0x2a19c078dc8>,
#   <matplotlib.axis.XTick at 0x2a19c076f48>,
#   <matplotlib.axis.XTick at 0x2a19c0bef88>,
#   <matplotlib.axis.XTick at 0x2a19c0c3908>],
#  [Text(0, 0, 'film1'),
#   Text(1, 0, 'film2'),
#   Text(2, 0, 'film3'),
#   Text(3, 0, 'film4')])

# %%
plt.bar(range(len(new_files)),awards)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>

# %% [markdown]
# # histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_h = np.random.normal(150,15,230)

# %%
plt.hist(new_h)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([37,27,27,17])

ch_labels = ["first","second","third","fourth"]

plt.pie(x: labels = ch_labels)
plt.show()
# Out:
#   File "<ipython-input-73-2bc21a9856f1>", line 8
#     plt.pie(x: labels = ch_labels)
#              ^
# SyntaxError: invalid syntax
